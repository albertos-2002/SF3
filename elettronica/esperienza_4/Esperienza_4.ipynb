# %% [markdown]
# <a href="https://colab.research.google.com/github/albertos-2002/SF3/blob/main/elettronica/esperienza_4/Esperienza_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dati

# %% [markdown]
# Metrix:
#
# $r_{1B} = r_1 = 8.166k$ fondo scala $10k$
#
# $rf_{sum} = r_1 = 8.1596k$  fondo scala $100k$

# %% [markdown]
# #Foto oscilloscopio

# %% [markdown]
# screenshot o foto oscilloscopio (incluso il numero identificativo dello strumento) con
# $V_1$ e $V_2$ per le due onde a frequenza una doppia dell’altra

# %% [markdown]
# ![esp4.1.png](data:image/png;base64,...)

# %% [markdown]
# screenshot o foto oscilloscopio con $V_1$ e Vout per le due onde a frequenza una
# doppia dell’altra

# %% [markdown]
# ![esp4.2.png](data:image/png;base64,...)

# %% [markdown]
# screenshot o foto oscilloscopio con $V_1$ e $V_{out}$ per le due onde in battimento

# %% [markdown]
# ![esp4.3.png](data:image/png;base64,...)
