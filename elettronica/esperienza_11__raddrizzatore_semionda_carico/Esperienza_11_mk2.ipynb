# %% [markdown]
# <a href="https://colab.research.google.com/github/albertos-2002/SF3/blob/main/elettronica/esperienza_11__raddrizzatore_semionda_carico/Esperienza_11_mk2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %% [markdown]
# # 🟢 Misura delle componenti

# %% [markdown]
# Non è stato preso il fondo per il capacitore
#
# - Le misure di resistenze sono state fatte con il metrix
#
# - La misura di capacità con l'agilet

# %%
r1 = 2.164 *1000 #kohm
err_r1 = math.sqrt(1/3)* math.sqrt( ( r1*0.07/100 )**2 + (0.8)**2 )  #ipotesi uniforme
print("r1")
print(r1, " \pm ", err_r1)
print(100* err_r1/r1)

c_elt = 47.3 #microF
err_c_elt = math.sqrt(1/3)* math.sqrt( ( c_elt*1.9/100 )**2 + (0.2)**2 )
print("\nc_elt")
print(c_elt, " \pm ", err_c_elt)
print(100* err_c_elt/c_elt)

rl0 = 3.2757 *1000 #kohm
err_rl0 = math.sqrt(1/3)* math.sqrt( ( rl0*0.07/100 )**2 + (0.8)**2 )
print("\nrl0")
print(rl0, " \pm ", err_rl0)
print(100* err_rl0/rl0)

rl1 = 1.1733 *1000 #kohm
err_rl1 = math.sqrt(1/3)* math.sqrt( ( rl1*0.07/100 )**2 + (0.8)**2 )
print("\nrl1")
print(rl1, " \pm ", err_rl1)
print(100* err_rl1/rl1)

rl2 = 4.5982 *1000 #kohm
err_rl2 = math.sqrt(1/3)* math.sqrt( ( rl2*0.07/100 )**2 + (0.8)**2 )
print("\nrl2")
print(rl2, " \pm ", err_rl2)
print(100* err_rl2/rl2)

rl3 = 9.885 *1000 #kohm
err_rl3 = math.sqrt(1/3)* math.sqrt( ( rl3*0.07/100 )**2 + (0.8)**2 )
print("\nrl3")
print(rl3, " \pm ", err_rl3)
print(100* err_rl3/rl3)
# Out:
# r1
# 2164.0  \pm  0.9890431470197176
# 0.04570439681237142
#
# c_elt
# 47.3  \pm  0.5315579899377552
# 1.1238012472256982
#
# rl0
# 3275.7000000000003  \pm  1.4021178195976733
# 0.042803608987320975
#
# rl1
# 1173.3  \pm  0.6619542069005478
# 0.056418154512959
#
# rl2
# 4598.200000000001  \pm  1.9148792118216407
# 0.04164410447178549
#
# rl3
# 9885.0  \pm  4.021586761880606
# 0.040683730519783565

# %% [markdown]
# # 📐 Misure senza $C$, $R_L$

# %% [markdown]
# Onda seno in ingresso:
# - $f = 1 KHz$
# - $A = 5V$ ($V_{pp} = 10V$)

# %% [markdown]
# ![verifica-onda-in.png](data:image/png;base64,...)

# %% [markdown]
# ##Misura con il metrix

# %% [markdown]
# Il valore di tensione registrato ai capi del circuito con il multimetro in configurazione DC
#
# $V = 1.5109 V $

# %%
#calcoliamo l'incertezza
errore = math.sqrt(1/3)* math.sqrt( (1.5109*0.03/100)**2 + (0.0008)**2 )
print(errore)
# Out:
# 0.0005308652349074417

# %% [markdown]
# Il manuale del metrix riporta che per questa misura l'impedenza d'ingresso è pari a 10.5 $MΩ$ per la scala da $10V$

# %% [markdown]
# Possiamo calcolare il valore di resistenza considerando che è presente solo $R_1$, quindi calcolata la corrente dopo il diodo possiamo usarne la conservazione per vedere la corrente che arriva effettivamente alla "R_L" fittizzia e, conoscendo il potenziale possiamo ricavarcene il valore

# %% [markdown]
# ##Misura con l'oscilloscopio

# %% [markdown]
# ![massimo-senza-rl-senza-c1.png](data:image/png;base64,...)

# %% [markdown]
# Il valore massimo (dato dal picco-picco) è
#
# $V = 4.12 V$

# %%
#calcoliamo l'errore
errore = math.sqrt(1/3)* math.sqrt( (4.12*3/100)**2 + (0.1)**2 )
print(errore)
# Out:
# 0.09179135761787889

# %% [markdown]
# # 📐 Misura senza $R_L$ con $C$

# %% [markdown]
# Dalla foto dell'oscilloscopio possiamo vedere che la forma della curva è cambiata sensibilmente ed è comparso il fenomeno chiamato "ripple"
#
# Dalla teoria sappiamo che
#
# - la prima parte della curva è quella dove la tensione segue quella in ingresso, con un massimo a $V_{in} - V_{on}$, dove $V_{on}$ e la tensione di accensione del diodo
# - quando la tensione cala il diodo si spegne e la carica accumulata nel condensatore si scarica sulla resistenza di carico
# - il processo poi ricomincia da capo

# %% [markdown]
# ##Metrix

# %% [markdown]
# Il metrix misura una tensione di
#
# $V = 3.5439 V$

# %%
#calcoliamo l'incertezza
errore = math.sqrt(1/3)* math.sqrt( (3.5439*0.03/100)**2 + (0.0008)**2 )
print(errore)
# Out:
# 0.0007681862727446601

# %% [markdown]
# Il manuale del metrix riporta che per questa misura l'impedenza d'ingresso è pari a 10.5 $MΩ$ per la scala da $10V$

# %% [markdown]
# ##Oscilloscopio

# %% [markdown]
# ![massimo-senza-rl-con-c1.png](data:image/png;base64,...)

# %% [markdown]
# L'osiclloscipio riporta le seguenti misure (effettuate con i cursori orizzontali)

# %%
misura = (3.59-3.55) #V
print("espresse in mV")
print(misura*1000)
#errore = math.sqrt(1/3)* math.sqrt( ( (3.59*3/100)**2 + (0.1*0.05)**2 ) + ( (3.55*3/100)**2 + (0.1*0.05)**2 ) )
errore = math.sqrt(1/3)* math.sqrt( (misura*3/100)**2 + (0.1*0.05)**2 )
print(errore*1000)
# Out:
# espresse in mV
# 40.000000000000036
# 2.9687258770949767

# %% [markdown]
# # 📐 Misure con $ R_L, C$

# %% [markdown]
# ## Misure con il metrix

# %% [markdown]
# Il metrix misura una tensione di
#
# $V = 3.2847 \ V$
#
# sempre con scala 10 V e impedenza d'ingresso di 10 MΩ

# %%
#calcolo errore
errore = math.sqrt(1/3)* math.sqrt( (3.2847*0.03/100)**2 + (0.0008)**2 )
print(errore)
# Out:
# 0.0007328103138147915

# %% [markdown]
# Con l'aggiunta di $R_L$ il valore di tensione misurato è diminuito

# %% [markdown]
# Perchè la misura è cambiata ?
#
# . . . . . . . . . . . . .

# %% [markdown]
# ## Misure con l'oscilloscopio

# %% [markdown]
# ![12rl.png](data:image/png;base64,...)

# %%
misura = 3.40-3.36 #V
print("misura in mV")
print(misura*1000)
errore = math.sqrt(1/3)* math.sqrt( (misura*3/100)**2 + (0.1*0.05)**2 )
print(errore*1000)
# Out:
# misura in mV
# 40.000000000000036
# 2.9687258770949767

# %% [markdown]
# Il valore del ripple non è cambiato rispetto al caso precedente, ma la forma della curva è cambiata

# %% [markdown]
# # 📐 Variazione di $R_L$ e di $f$

# %% [markdown]
# ## ▶ Metrix

# %% [markdown]
# Le misure sono state svolte il configurazione DC
#
# Scala 10V

# %% [markdown]
# Misure di variazione di $R_L$
#
# $R_{L1}$:   $ V = 2.9471 \ V $
#
# $R_{L2}$:   $ V = 3.3551 \ V $
#
# $R_{L3}$:   $ V = 3.4530 \ V $

# %%
#calcolo degli errori
err1 = math.sqrt(1/3)* math.sqrt( (2.9471*0.03/100)**2 + (0.0008)**2 )
print(err1)
err2 = math.sqrt(1/3)* math.sqrt( (3.3551*0.03/100)**2 + (0.0008)**2 )
print(err2)
err3 = math.sqrt(1/3)* math.sqrt( (3.4530*0.03/100)**2 + (0.0008)**2 )
print(err3)
# Out:
# 0.0006884005270431839
# 0.0007423167879236825
# 0.0007556650073500382

# %% [markdown]
# Misure di variazione di frequenza con $R_L = R_{L0}$
#
# $f = 0.1 KHz$ :   $ V = 3.2655 \ V$
#
# $f = 2 KHz$ :   $ V = 3.2895 \ V$
#
# $f = 4 KHz$ :   $ V = 3.2902 \ V$

# %%
#calcolo degli errori
err1 = math.sqrt(1/3)* math.sqrt( (3.2655*0.03/100)**2 + (0.0008)**2 )
print(err1)
err2 = math.sqrt(1/3)* math.sqrt( (3.2895*0.03/100)**2 + (0.0008)**2 )
print(err2)
err3 = math.sqrt(1/3)* math.sqrt( (3.2902*0.03/100)**2 + (0.0008)**2 )
print(err3)
# Out:
# 0.00073023149811093
# 0.0007334559569826489
# 0.0007335501445254669

# %% [markdown]
# ## ▶ Oscilloscopio

# %% [markdown]
# ### ▶ ▶ **Cambio di $R_L$**

# %% [markdown]
# Le misure di resistenza sono leggermente cambiate rispetto alla prima presa dati
#
# Riportiamo teutte le misure, dato che le variazioni sono superiori all'errore sperimentale dato dal metrix

# %%
r1 = 2.23 *1000 #kohm
err_r1 = math.sqrt(1/3)* math.sqrt( ( r1*0.07/100 )**2 + (0.8)**2 )  #ipotesi uniforme
print("r1")
print(r1, " \pm ", err_r1)
print(100* err_r1/r1)

rl0 = 3.22 *1000 #kohm
err_rl0 = math.sqrt(1/3)* math.sqrt( ( rl0*0.07/100 )**2 + (0.8)**2 )
print("\nrl0")
print(rl0, " \pm ", err_rl0)
print(100* err_rl0/rl0)

rl1 = 1.477 *1000 #kohm
err_rl1 = math.sqrt(1/3)* math.sqrt( ( rl1*0.07/100 )**2 + (0.8)**2 )
print("\nrl1")
print(rl1, " \pm ", err_rl1)
print(100* err_rl1/rl1)

rl2 = 4.58 *1000 #kohm
err_rl2 = math.sqrt(1/3)* math.sqrt( ( rl2*0.07/100 )**2 + (0.8)**2 )
print("\nrl2")
print(rl2, " \pm ", err_rl2)
print(100* err_rl2/rl2)

rl3 = 9.86 *1000 #kohm
err_rl3 = math.sqrt(1/3)* math.sqrt( ( rl3*0.07/100 )**2 + (0.8)**2 )
print("\nrl3")
print(rl3, " \pm ", err_rl3)
print(100* err_rl3/rl3)
# Out:
# r1
# 2230.0  \pm  1.012706110708663
# 0.045412830076621655
#
# rl0
# 3220.0  \pm  1.3808832921962184
# 0.042884574291808024
#
# rl1
# 1477.0  \pm  0.7547514403210281
# 0.05110030063107841
#
# rl2
# 4580.0  \pm  1.9077417714844604
# 0.041653750469093025
#
# rl3
# 9860.0  \pm  4.011550157565859
# 0.04068509287592149

# %% [markdown]
# ####**RL1**

# %% [markdown]
# ####Tensione

# %% [markdown]
# ![rl1 tensione.png](data:image/png;base64,...)

# %%
misura = 3.11-3.03 #V
print("misura in mV")
print(misura*1000)
errore = math.sqrt(1/3)* math.sqrt( (misura*3/100)**2 + (0.1*0.05)**2 )
print(errore*1000)
# Out:
# misura in mV
# 80.00000000000007
# 3.2020826556060884

# %% [markdown]
# ####Periodo

# %% [markdown]
# ![rl1 periodo.png](data:image/png;base64,...)

# %% [markdown]
# ####Tempo scarica

# %% [markdown]
# ![rl1 scarica.png](data:image/png;base64,...)

# %% [markdown]
# ####**RL2**

# %% [markdown]
# ####Tensione

# %% [markdown]
# ![rl2 tensione.png](data:image/png;base64,...)

# %%
misura = 3.41-3.36 #V
print("misura in mV")
print(misura*1000)
errore = math.sqrt(1/3)* math.sqrt( (misura*3/100)**2 + (0.1*0.05)**2 )
print(errore*1000)
# Out:
# misura in mV
# 50.00000000000027
# 3.0138568866708564

# %% [markdown]
# ####Periodo

# %% [markdown]
# ![rl2 periodo.png](data:image/png;base64,...)

# %% [markdown]
# ####Tempo di scarica

# %% [markdown]
# ![rl2 scarica.png](data:image/png;base64,...)

# %% [markdown]
# ####**RL3**

# %% [markdown]
# ####Tensione

# %% [markdown]
# ![rl3 tensione.png](data:image/png;base64,...)

# %%
misura = 3.50-3.45 #V
print("misura in mV")
print(misura*1000)
errore = math.sqrt(1/3)* math.sqrt( (misura*3/100)**2 + (0.1*0.05)**2 )
print(errore*1000)
# Out:
# misura in mV
# 49.99999999999982
# 3.0138568866708537

# %% [markdown]
# ####Periodo

# %% [markdown]
# ![rl3 periodo.png](data:image/png;base64,...)

# %% [markdown]
# ####Tempo di scarica

# %% [markdown]
# ![rl3 scarica.png](data:image/png;base64,...)

# %% [markdown]
# ### ▶ ▶ **Regime di frequenza**

# %% [markdown]
# ![100hz.png](data:image/png;base64,...)

# %%
misura = 3.52-3.07 #V
print("misura in mV")
print(misura*1000)
errore = math.sqrt(1/3)* math.sqrt( (misura*3/100)**2 + (0.1*0.05)**2 )
print(errore*1000)
# Out:
# misura in mV
# 450.00000000000017
# 8.311638426527791

# %% [markdown]
# ![2khz.png](data:image/png;base64,...)

# %%
misura = 3.33-3.30 #V
print("misura in mV")
print(misura*1000)
errore = math.sqrt(1/3)* math.sqrt( (misura*3/100)**2 + (0.1*0.05)**2 )
print(errore*1000)
# Out:
# misura in mV
# 30.00000000000025
# 2.93314393327933

# %% [markdown]
# ![4khz.png](data:image/png;base64,...)

# %%
misura = 3.32-3.30 #V
print("misura in mV")
print(misura*1000)
errore = math.sqrt(1/3)* math.sqrt( (misura*3/100)**2 + (0.1*0.05)**2 )
print(errore*1000)
# Out:
# misura in mV
# 20.000000000000018
# 2.907461664980871

# %% [markdown]
# # ⏳ Simulazione
