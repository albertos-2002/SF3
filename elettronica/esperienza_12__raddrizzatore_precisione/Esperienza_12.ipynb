# %% [markdown]
# <a href="https://colab.research.google.com/github/albertos-2002/SF3/blob/main/elettronica/esperienza_12__raddrizzatore_precisione/Esperienza_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %% [markdown]
# # 🔴 Misura delle componenti

# %%
r1a =
err_r1a = math.sqrt( ()**2 + ()**2 )
print("ohm\n", r1a*1000)
print("errore\n", err_r1a*1000)

r1b =
err_r1b = math.sqrt( ()**2 + ()**2 )
print("\nohm\n", r1b*1000)
print("errore\n", err_r1b*1000)

r1c =
err_r1c = math.sqrt( ()**2 + ()**2 )
print("\nohm\n", r1c*1000)
print("errore\n", err_r1c*1000)

r1d =
err_r1d = math.sqrt( ()**2 + ()**2 )
print("\nohm\n", r1d*1000)
print("errore\n", err_r1d*1000)

r2 =
err_r2 = math.sqrt( ()**2 + ()**2 )
print("\nohm\n", r2*1000)
print("errore\n", err_r2*1000)

# %% [markdown]
# # 🟠 Tensione $V_{out}$ e $V_{in}$

# %% [markdown]
# Differenza tra i picchi alternati

# %% [markdown]
# ![vin vout amplificazione.png](data:image/png;base64,...)

# %% [markdown]
# Ampiezza picco-picco (base e picco massimo)

# %% [markdown]
# ![vin vout picco.png](data:image/png;base64,...)

# %% [markdown]
# # 🟠 Tensione $V_{out}'$ e $V_{in}$

# %% [markdown]
# ![vin voprimo.png](data:image/png;base64,...)

# %% [markdown]
# # 🟠 Tensione $V_2$ e $V_{in}$

# %% [markdown]
# ![vin v2.png](data:image/png;base64,...)

# %% [markdown]
# # 🔴 Soluzione teorica

# %% [markdown]
# # ⏳ Simulazione
